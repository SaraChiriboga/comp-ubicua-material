# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_excel('smartphone.xlsx')

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.head(5)
# Out:
#    dt           Time       Ax       Ay       Az        Mx        My       Mz  \
# 0   0  1599934986529  0.01916  0.11259  9.84494  15.78117 -40.85251  1.12512
# 1  32  1599934986561  0.01389  0.13319  9.83440  15.78117 -40.85251  1.12512
# 2   7  1599934986568  0.01725  0.15187  9.83200  15.78117 -40.85251  1.12512
# 3   7  1599934986575  0.01581  0.14660  9.81667  15.78117 -40.85251  1.12512
# 4  50  1599934986625  0.00719  0.13990  9.75726  15.78117 -40.85251  1.12512
#
#         Gx       Gy       Gz
# 0  0.01243  0.00876 -0.00262
# 1  0.01243  0.00876 -0.00262
# 2  0.01243  0.00876 -0.00262
# 3  0.01243  0.00876 -0.00262
# 4  0.00178  0.00663 -0.00582

# %%
df1['Mx']
# Out:
# 0       15.78117
# 1       15.78117
# 2       15.78117
# 3       15.78117
# 4       15.78117
#           ...
# 4705    14.87938
# 4706    14.87938
# 4707    16.47911
# 4708    16.47911
# 4709    16.47911
# Name: Mx, Length: 4710, dtype: float64

# %%
df1['Az']
# Out:
# 0       9.84494
# 1       9.83440
# 2       9.83200
# 3       9.81667
# 4       9.75726
#          ...
# 4705    9.79511
# 4706    9.79511
# 4707    9.79655
# 4708    9.80997
# 4709    9.79751
# Name: Az, Length: 4710, dtype: float64

# %%
fig = plt.figure(figsize=(20,30))

plt.subplot(211)
plt.title('Acelerometro Celular', fontsize=24)
plt.xlabel('Muestras', fontsize=24)
plt.ylabel('Datos Acc X', fontsize=24)
plt.plot(df1['Ax'], 'r')
plt.grid(True)
